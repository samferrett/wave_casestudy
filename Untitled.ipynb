# %%
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
nc=xr.load_dataset('./wave_input/Kelvin_122018_latsub_ERA5_6hr.nc')

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 124, lat: 3, lon: 360)
# Coordinates:
#   * lat                  (lat) float64 0.0 8.0 16.0
#   * lon                  (lon) float32 0.0 1.0 2.0 3.0 ... 357.0 358.0 359.0
#   * time                 (time) datetime64[ns] 2018-12-01 ... 2018-12-31T18:0...
# Data variables:
#     eastward_wind        (time, lat, lon) float64 1.933 1.864 ... -0.07902
#     geopotential_height  (time, lat, lon) float64 4.039 3.894 ... -0.1651
# Attributes:
#     Conventions:  CF-1.5
#     history:      Tue Nov  2 10:22:36 2021: ncks -C -O -x -v day_of_year uz_K...
#     NCO:          netCDF Operators version 4.9.7 (Homepage = http://nco.sf.ne...
